# %% [markdown]
# <a href="https://colab.research.google.com/github/Chetanmeena344/portfolio/blob/main/Sporty%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib as mp

# %%
import seaborn as sn

# %%
import plotly.express as px

# %%
import warnings

# %%
df = pd.read_csv('/content/Most_Streamed_Spotify_Songs_2024[1].csv', encoding='latin-1')

# %%
df.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# ...

# %%
df.columns
# Out:
# Index(['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC',
#        'All Time Rank', 'Track Score', 'Spotify Streams',
#        'Spotify Playlist Count', 'Spotify Playlist Reach',
#        'Spotify Popularity', 'YouTube Views', 'YouTube Likes', 'TikTok Posts',
#        'TikTok Likes', 'TikTok Views', 'YouTube Playlist Reach',
#        'Apple Music Playlist Count', 'AirPlay Spins', 'SiriusXM Spins',
#        'Deezer Playlist Count', 'Deezer Playlist Reach',
#        'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations',
#        'Soundcloud Streams', 'Shazam Counts', 'TIDAL Popularity',
#        'Explicit Track'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Track Score  Spotify Popularity  Apple Music Playlist Count  \
# count  4600.000000         3796.000000                  4039.00000
# mean     41.844043           63.501581                    54.60312
# std      38.543766           16.186438                    71.61227
# min      19.400000            1.000000                     1.00000
# 25%      23.300000           61.000000                    10.00000
# 50%      29.900000           67.000000                    28.00000
# 75%      44.425000           73.000000                    70.00000
# max     725.400000           96.000000                   859.00000
#
#        Deezer Playlist Count  Amazon Playlist Count  TIDAL Popularity  \
# count            3679.000000            3545.000000               0.0
# mean               32.310954              25.348942               NaN
# std                54.274538              25.989826               NaN
# min                 1.000000               1.000000               NaN
# ...

# %%
df.dtypes
# Out:
# Track                          object
# Album Name                     object
# Artist                         object
# Release Date                   object
# ISRC                           object
# All Time Rank                  object
# Track Score                   float64
# Spotify Streams                object
# Spotify Playlist Count         object
# Spotify Playlist Reach         object
# Spotify Popularity            float64
# YouTube Views                  object
# YouTube Likes                  object
# TikTok Posts                   object
# TikTok Likes                   object
# TikTok Views                   object
# YouTube Playlist Reach         object
# Apple Music Playlist Count    float64
# AirPlay Spins                  object
# SiriusXM Spins                 object
# Deezer Playlist Count         float64
# Deezer Playlist Reach          object
# Amazon Playlist Count         float64
# Pandora Streams                object
# Pandora Track Stations         object
# ...

# %%
pd.reset_option('display.max_columns', )

# %%
df
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4595                For the Last Time                 For the Last Time
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC All Time Rank  Track Score  \
# ...

# %%
df.tail()
# Out:
#                                 Track                        Album Name  \
# 4595                For the Last Time                 For the Last Time
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#             Artist Release Date          ISRC All Time Rank  Track Score  \
# 4595   $uicideboy$     9/5/2017  QM8DG1703420         4,585         19.4
# 4596    Atif Aslam    7/27/2018  INT101800122         4,575         19.4
# 4597      Lil Baby    2/28/2020  USUG12000043         4,571         19.4
# 4598  Arijit Singh    11/8/2016  INY091600067         4,591         19.4
# 4599     Arcï¿½ï¿½    4/11/2017  USB271700107         4,593         19.4
#
#      Spotify Streams Spotify Playlist Count Spotify Playlist Reach  ...  \
# ...

# %%
df.isna ().sum()
# Out:
# Track                            0
# Album Name                       0
# Artist                           5
# Release Date                     0
# ISRC                             0
# All Time Rank                    0
# Track Score                      0
# Spotify Streams                113
# Spotify Playlist Count          70
# Spotify Playlist Reach          72
# Spotify Popularity             804
# YouTube Views                  308
# YouTube Likes                  315
# TikTok Posts                  1173
# TikTok Likes                   980
# TikTok Views                   981
# YouTube Playlist Reach        1009
# Apple Music Playlist Count     561
# AirPlay Spins                  498
# SiriusXM Spins                2123
# Deezer Playlist Count          921
# Deezer Playlist Reach          928
# Amazon Playlist Count         1055
# Pandora Streams               1106
# Pandora Track Stations        1268
# Soundcloud Streams            3333
# Shazam Counts                  577
# ...

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (4598, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4598 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4598 non-null   object
#  1   Album Name                  4598 non-null   object
#  2   Artist                      4593 non-null   object
#  3   Release Date                4598 non-null   object
#  4   ISRC                        4598 non-null   object
#  5   All Time Rank               4598 non-null   object
#  6   Track Score                 4598 non-null   float64
#  7   Spotify Streams             4485 non-null   object
#  8   Spotify Playlist Count      4528 non-null   object
#  9   Spotify Playlist Reach      4526 non-null   object
#  10  Spotify Popularity          3794 non-null   float64
#  11  YouTube Views               4290 non-null   object
#  12  YouTube Likes               4283 non-null   object
# ...

# %%
df.describe()
# Out:
#        Track Score  Spotify Popularity  Apple Music Playlist Count  \
# count  4598.000000         3794.000000                 4037.000000
# mean     41.850892           63.498682                   54.613574
# std      38.550706           16.189952                   71.628469
# min      19.400000            1.000000                    1.000000
# 25%      23.300000           61.000000                   10.000000
# 50%      29.900000           67.000000                   28.000000
# 75%      44.475000           73.000000                   70.000000
# max     725.400000           96.000000                  859.000000
#
#        Deezer Playlist Count  Amazon Playlist Count  TIDAL Popularity  \
# count            3677.000000            3543.000000               0.0
# mean               32.321730              25.346034               NaN
# std                54.287051              25.993157               NaN
# min                 1.000000               1.000000               NaN
# ...

# %%
df.drop("TIDAL Popularity",axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC',
#        'All Time Rank', 'Track Score', 'Spotify Streams',
#        'Spotify Playlist Count', 'Spotify Playlist Reach',
#        'Spotify Popularity', 'YouTube Views', 'YouTube Likes', 'TikTok Posts',
#        'TikTok Likes', 'TikTok Views', 'YouTube Playlist Reach',
#        'Apple Music Playlist Count', 'AirPlay Spins', 'SiriusXM Spins',
#        'Deezer Playlist Count', 'Deezer Playlist Reach',
#        'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations',
#        'Soundcloud Streams', 'Shazam Counts', 'Explicit Track'],
#       dtype='object')

# %%
df['Album Name'].value_counts().nlargest(20)
# Out:
# Album Name
# Un Verano Sin Ti                                        20
# THE TORTURED POETS DEPARTMENT                           18
# nadie sabe lo que va a pasar maï¿½ï¿                    16
# For All The Dogs                                        15
# UTOPIA                                                  15
# Full Circle: The Live Anthology                         13
# WE DON'T TRUST YOU                                      11
# Papercuts                                               11
# Her Loss                                                11
# HIT ME HARD AND SOFT                                    10
# HEROES & VILLAINS                                        8
# Midnights                                                7
# Amor Prohibido (Remasterizado 2024/30th Anniversary)     7
# Certified Lover Boy                                      7
# YHLQMDLG                                                 7
# 1989 (Taylor's Version)                                  7
# ...

# %%
for i in df.columns:
    print(f"--------------{i}_____TOP 20 VALUES OF_____{i}---------------------")
    print(df[i].value_counts().nlargest(20))
    print("--------"*10)
# Out:
# --------------Track_____TOP 20 VALUES OF_____Track---------------------
# Track
# Danza Kuduro - Cover         13
# Cake By The Ocean - Cover     9
# ýýýýýýýýýýýý                  7
# ýýýýýý                        6
# Flowers                       4
# Alone                         4
# ýýýýýýýýýýýýýýý               4
# Baby Shark                    3
# Espresso                      3
# Stay With Me                  3
# Karma                         3
# Body                          3
# Kill Bill                     3
# As It Was                     3
# Attention                     3
# Daylight                      3
# Paint The Town Red            3
# Without Me                    3
# Animals                       3
# Houdini                       3
# Name: count, dtype: int64
# --------------------------------------------------------------------------------
# --------------Album Name_____TOP 20 VALUES OF_____Album Name---------------------
# Album Name
# ...

# %%
top_albums=df['Album Name'].value_counts().nlargest(50)

# %%
df
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4595                For the Last Time                 For the Last Time
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC All Time Rank  Track Score  \
# ...

# %%
import matplotlib.pyplot as mp
import seaborn as sn


top_albums_df = top_albums.reset_index()
top_albums_df.columns = ['Album Name', 'Count']
mp.figure(figsize=(15, 5))
sn.barplot(x='Album Name', y='Count', data=top_albums_df, palette='viridis')
mp.title('Top 50 Albums by Count', fontsize=15)
mp.xlabel('Album Name', fontsize=12)
mp.ylabel('Count', fontsize=12)
mp.xticks(rotation=45, ha='right')
mp.show()
# Out:
# <ipython-input-61-06578b0fc77f>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(x='Album Name', y='Count', data=top_albums_df, palette='viridis')

# %%
df.columns
# Out:
# Index(['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC',
#        'All Time Rank', 'Track Score', 'Spotify Streams',
#        'Spotify Playlist Count', 'Spotify Playlist Reach',
#        'Spotify Popularity', 'YouTube Views', 'YouTube Likes', 'TikTok Posts',
#        'TikTok Likes', 'TikTok Views', 'YouTube Playlist Reach',
#        'Apple Music Playlist Count', 'AirPlay Spins', 'SiriusXM Spins',
#        'Deezer Playlist Count', 'Deezer Playlist Reach',
#        'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations',
#        'Soundcloud Streams', 'Shazam Counts', 'Explicit Track'],
#       dtype='object')

# %%
top_Artist=df['Artist'].value_counts().nlargest(50)

# %%
top_Artist
# Out:
# Artist
# Taylor Swift       63
# Drake              63
# Bad Bunny          60
# KAROL G            32
# The Weeknd         31
# Travis Scott       30
# Billie Eilish      27
# Ariana Grande      26
# Future             23
# Post Malone        22
# Peso Pluma         22
# Juice WRLD         21
# Morgan Wallen      20
# Lil Baby           20
# Olivia Rodrigo     20
# Doja Cat           19
# Rauw Alejandro     19
# Kendrick Lamar     18
# Feid               17
# Bizarrap           17
# 21 Savage          17
# Calvin Harris      17
# Dua Lipa           17
# XXXTENTACION       16
# Imagine Dragons    16
# J Balvin           16
# Metro Boomin       15
# Gunna              15
# Ed Sheeran         15
# Eminem             15
# Kanye West         15
# Shakira            14
# SZA                14
# Rod Wave           14
# Justin Bieber      14
# MUSIC LAB JPN      14
# Marshmello         14
# Fuerza Regida      14
# BTS                14
# BLACKPINK          14
# Nicki Minaj        13
# ...

# %%
top_Track_df = top_Artist.reset_index()
top_Track_df.columns = ['Artist Name', 'Count']
mp.figure(figsize=(15, 5))
sn.barplot(x='Artist Name', y='Count', data=top_Track_df, palette='viridis')
mp.title('Top 50 Artist by Count', fontsize=15)
mp.xlabel('Artist Name', fontsize=12)
mp.ylabel('Count', fontsize=12)
mp.xticks(rotation=45, ha='right')
mp.show()
# Out:
# <ipython-input-66-4939fe251de5>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(x='Artist Name', y='Count', data=top_Track_df, palette='viridis')

# %%
top_Track=df['Track'].value_counts().nlargest(50)

# %%
top_Track_df = top_Track.reset_index()
top_Track_df.columns = ['Track Name', 'Count']
mp.figure(figsize=(15, 5))
sn.barplot(x='Track Name', y='Count', data=top_Track_df, palette='viridis')
mp.title('Top 50 Track by Count', fontsize=15)
mp.xlabel('Track Name', fontsize=12)
mp.ylabel('Count', fontsize=12)
mp.xticks(rotation=45, ha='right')
mp.show()
# Out:
# <ipython-input-68-78d654725031>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(x='Track Name', y='Count', data=top_Track_df, palette='viridis')

# %%
top_ranked_artist=df[['Artist','All Time Rank']]

# %%
top_20artist=top_ranked_artist.head(20)

# %%
top_20artist
# Out:
#             Artist All Time Rank
# 0    Tommy Richman             1
# 1   Kendrick Lamar             2
# 2          Artemas             3
# 3      Miley Cyrus             4
# 4           Eminem             5
# 5      Jack Harlow             6
# 6     Benson Boone             7
# 7       FloyyMenor             8
# 8    MUSIC LAB JPN             9
# 9      Central Cee            10
# 10     Post Malone            11
# 11     Teddy Swims            12
# 12   Billie Eilish            13
# 13          Future            14
# 14  Kids With Buns            15
# 15     Myke Towers            16
# 16    Taylor Swift            17
# 17      Tate McRae            18
# 18   Billie Eilish            19
# 19    Harry Styles            20

# %%
least_20artist=top_ranked_artist.tail(20)

# %%
least_20artist
# Out:
#                     Artist All Time Rank
# 4580          Dominic Fike         4,535
# 4581                    SR         4,565
# 4582  Bring Me The Horizon         4,544
# 4583              347aidan         4,541
# 4584              J Balvin         4,553
# 4585             Baby Keem         4,537
# 4586              Serranow         4,556
# 4587              Brytiago         4,554
# 4588                 Steps         4,562
# 4589            Kerim Araz         4,534
# 4590          Harry Styles         4,558
# 4591          Jaymes Young         4,540
# 4592         Jaques Raupï¿         4,595
# 4593              Thaman S         4,587
# 4594           BUSHIDO ZHO         4,599
# 4595           $uicideboy$         4,585
# 4596            Atif Aslam         4,575
# 4597              Lil Baby         4,571
# 4598          Arijit Singh         4,591
# 4599             Arcï¿½ï¿½         4,593
